# %% [markdown]
# ![dls.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Классификация изображений</b></h3>

# %% [markdown]
# # Домашнее задание. Классификация изображений
#
# Сегодня вам предстоить помочь телекомпании FOX в обработке их контента. Как вы знаете, сериал "Симпсоны" идет на телеэкранах более 25 лет, и за это время скопилось очень много видеоматериала. Персоонажи менялись вместе с изменяющимися графическими технологиями, и Гомер Симпсон-2018 не очень похож на Гомера Симпсона-1989. В этом задании вам необходимо классифицировать персонажей, проживающих в Спрингфилде. Думаю, нет смысла представлять каждого из них в отдельности.

# %% [markdown]
# В нашем тесте будет 991 картинка, для которых вам будет необходимо предсказать класс.

# %% [markdown]
# ## Шаг 1. Установка зависимостей

# %% [markdown]
# ####Установим необходимые библиотеки и проверим доступность CUDA

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
#
# if it prints otherwise, then you need to enable GPU:
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# !nvidia-smi
# Out:
# Sat Feb 14 21:42:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8             14W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import pickle
import numpy as np
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from torchvision.transforms import v2

import torchsummary

from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

# в sklearn не все гладко, чтобы в colab удобно выводить картинки
# мы будем игнорировать warnings
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %% [markdown]
# #### Проверим версии Python и библиотек
# Посмотрим, какие версии установлены:

# %%
# !python --version
from importlib.metadata import version
for b in ['torch', 'torchvision', 'tqdm', 'matplotlib', 'seaborn', 'Pillow']:
    print(b + ' version: '+ version(b))
# Out:
# Python 3.12.12
# torch version: 2.9.0+cu128
# torchvision version: 0.24.0+cu128
# tqdm version: 4.67.3
# matplotlib version: 3.10.0
# seaborn version: 0.13.2
# Pillow version: 11.3.0

# %% [markdown]
# Сверим с версиями питона и библиотек, на которых работал эталонный ноутбук:
#
# - Python 3.12.12
# - torch version: 2.8.0+cu126
# - torchvision version: 0.23.0+cu126
# - tqdm version: 4.67.1
# - matplotlib version: 3.10.0
# - seaborn version: 0.13.2
# - Pillow version: 11.3.0

# %% [markdown]
#  #### Определим константы, которые будем использовать в по ходу ноутбука

# %%
# разные режимы датасета
DATA_MODES = ['train', 'val', 'test']

# работаем на видеокарте
DEVICE = torch.device("cuda")

#определим директории с тренировочными и тестовыми файлами
TRAIN_DIR = Path('/content/train') #Path('./data/train/')
TEST_DIR = Path('/content/testset') #Path('./data/testset')

# параметры нормировки изображений по трем каналам перед подачей в модель
NORMALIZE_MEAN = [0.485, 0.456, 0.406]
NORMALIZE_STD = [0.229, 0.224, 0.225]

# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = [224, 224]

# %% [markdown]
# ## Шаг 2. Загрузка и обработка данных

# %% [markdown]
# #### Скачаем изображения по ссылке

# %%
# !gdown 1RxBQiZgRAfio2tWhEE7lzZ6IaJzLheH1
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1RxBQiZgRAfio2tWhEE7lzZ6IaJzLheH1
# From (redirected): https://drive.google.com/uc?id=1RxBQiZgRAfio2tWhEE7lzZ6IaJzLheH1&confirm=t&uuid=acab5c5f-34c8-463e-85c2-1ecd1d60a830
# To: /content/journey-springfield.zip
# 100% 546M/546M [00:07<00:00, 69.9MB/s]

# %%
# !unzip -q /content/journey-springfield.zip

# %% [markdown]
# Посмотрите на структуру файлов в папках train и testset.
#
# В train лежат данные, которые мы будем использовать для обучения модели. Изображения персонажей разложены по папкам, которые названы по именам персонажей. Названия папок мы в дальнейшем будет использовать в качестве текстовых меток классов.
#
# В testset находятся изображения, для которых вам надо будет сделать прогноз наиболее вероятного класса.

# %% [markdown]
# Для обращения к файлам сформируем списки имен файлов обучающей+валидационнной и тестовой выборок. Это полные имена, включающие путь к файлам.

# %%
train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %% [markdown]
# Кодировать имена персонажей в числовые метки класса и обратно будем при помощи `LabelEncoder`.
#
# Для train выборки сформируем список текстовых меток всех изображений - имя родительской директории, которая одновременно является и именем персонажа. Зададим числовые метки классов нашего энкодера при помощи метода `fit`.
#
# Далее будем применять метод `transform` для преобразования текстовых меток в числовые, и метод `inverse_transform` для преобразования числовых меток в текстовые.

# %%
label_encoder = LabelEncoder()

train_val_labels = [path.parent.name for path in train_val_files]

label_encoder.fit(train_val_labels)
# Out:
# LabelEncoder()

# %% [markdown]
# Разделим train выборку на обучающую и валидационнную части. Для того, чтобы персонажи были пропорционально представлены в обучающей и валидационнной подвыборках, применим стратификацию по меткам класса.

# %%
from sklearn.model_selection import train_test_split

train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

# %% [markdown]
# ####Создадим Datasets и Dataloaders

# %% [markdown]
# Полезная статья, которой мы вдохновились при создании класса `SimpsonsDataset`:
# https://jhui.github.io/2018/02/09/PyTorch-Data-loading-preprocess_torchvision/

# %% [markdown]
# У нас есть набор файлов-картинок, которые требуется преобразовать в тензоры, и добавить к ним числовые метки классов. Реализуем это с помощью созданного нами класса `SimpsonsDataset`, который из списка файлов создаст необходимый нам Dataset.
#
# Будем действовать согласно инструкции из документации (https://docs.pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files):
# - наш класс будет наследовать от класса Dataset
# - мы переопределим методы `__init__`, `__len__` и `__getitem__`, а также для удобства добавим несколько методов для загрузки и преобразования изображений.

# %% [markdown]
# Важно разобраться, что делает метод self.transform_images_to_tensors().
#
# `Compose` объединяет последовательность следующих преобразований:
# - `PILToTensor` конвертирует  `PIL Image` в тензор с параметрами в диапазоне $[0, 255]$ (как все пиксели в исходном изображении)
# - `ToDtype` преобразует тензор в `FloatTensor` размера ($C \times H \times W$) со значениями пикселей в диапазоне $[0,1]$
# - затем `Normalize` производится масштабирование:
# $\text{input} = \frac{\text{input} - \text{mean}}{\text{std}} $, <br>      где константы mean и std - средние и дисперсии по каналам в датасете ImageNet
# - наконец, `Resize` преобразует картинки к размеру $224 \times 224$ (в описании датасета указано, что картинки разного размера, так как брались напрямую с видео, поэтому следует привести их к одному размеру).
#
# Сейчас аугментация не изображений не производится, поэтому для обучающих и валидационных/тестовых изображений производится одинаковая трансформация. В дальнейшем, если вы захотите добавить аугментацию, вы можете сделать это, например, модифицировав метод `transform_images_to_tensors`. Подробнее про трансформацию изображений вы можете почитать в документации: https://docs.pytorch.org/vision/main/transforms.html

# %%
class SimpsonsDataset(Dataset):
    def __init__(self, files, label_encoder, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode
        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.label_encoder = label_encoder
        self.len_ = len(self.files)

    def __len__(self):
        return self.len_ # сейчас self.__len__() возвращает количество картинок, подаваемых на вход.
        # Если вы решите перевзвесить размеры категорий внутри класса -
        # не забудьте изменить вывод self.__len__()

    def __getitem__(self, index):
        x = self.load_image(self.files[index])
        x = self.transform_images_to_tensors(x)

        if self.mode == 'test':
            return x
        else:
            path = self.files[index]
            y = self.label_encoder.transform([path.parent.name,]).item()
            return x, y

    # принимает путь к файлу изображения и возвращает само изображение
    def load_image(self, file):
        image = Image.open(file)
        image.load()
        return image

    # преобразует изображение в тензор
    def transform_images_to_tensors(self, image):
      if self.mode == 'train':
        transform = v2.Compose([
            v2.PILToTensor(),
            v2.ToDtype(torch.float32, scale=True),
            v2.Normalize(NORMALIZE_MEAN, NORMALIZE_STD),
            #v2.ColorJitter(brightness = 0.1, contrast = 0.1, saturation = 0.1),
            v2.Resize(RESCALE_SIZE),
          ])
      else:
        transform = v2.Compose([
            v2.PILToTensor(),
            v2.ToDtype(torch.float32, scale=True),
            v2.Normalize(NORMALIZE_MEAN, NORMALIZE_STD),
            v2.Resize(RESCALE_SIZE),
          ])

      tensor_transformed = transform(image)
      return(tensor_transformed)

# %%
train_dataset = SimpsonsDataset(train_files, label_encoder = label_encoder, mode='train')
val_dataset = SimpsonsDataset(val_files, label_encoder, mode='val')

# %%
batch_size = 64

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
loaders = {'train':train_loader, 'val': val_loader}

# %% [markdown]
# #### Посмотрим на изображения персонажей

# %% [markdown]
# Напишем функцию для визуализации картинок. Это аналог Imshow, которая будет принимать на вход тензоры

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %% [markdown]
# Проверим, как работает наша функция. Возьмем один батч из лоадера и подадим на вход функции первый тензор из этого батча. Заодно посмотрим, как работает кодировщик меток класса.

# %%
image_tensor, label = next(iter(train_loader))
print(f"Числовая метка класса: {label[0]}")
print(f"Текстовая метка класса: {label_encoder.inverse_transform([label[0],])}")
imshow(image_tensor[0])
# Out:
# Числовая метка класса: 29
# Текстовая метка класса: ['nelson_muntz']

# %%
# uncomment if you have problem with pillow
# def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
# Image.register_extension = register_extension
# def register_extensions(id, extensions):
#     for extension in extensions: register_extension(id, extension)
# Image.register_extensions = register_extensions

# %% [markdown]
# Давайте посмотрим на наших героев внутри датасета.

# %%
def show_images(n_rows, n_cols, dataset):
  # функция выводит изображения в n_rows рядов и n_cols столбцов
  fig, ax = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 4, n_rows * 4), \
                        sharey=True, sharex=True)

  for fig_x in ax.flatten(): # цикл повторяется (n_rows * n_cols) раз
    random_characters = int(np.random.uniform(0, len(dataset))) # берем случайное число в диапазоне [0; len(dataset))
    im_val, label = dataset[random_characters] # получаем изображение (тензорная форма)
    img_label = " ".join(map(lambda x: x.capitalize(), \
                             label_encoder.inverse_transform([label])[0].split('_')))  # числовую метку класса преобразуем в текстовую и немного отформатируем
    imshow(im_val.data.cpu(), title=img_label, plt_ax=fig_x) # отобразим изображение и метку класса с помощью написанной ранее функции imshow()
    fig_x.set_axis_off()
  return None

# %% [markdown]
# **!** Обратите внимание, что возможно, датасет требует дополнительной фильтрации, так как лейблы не всегда точно соответствуют картинкам. Очистка датасета - это один из способов повысить качество модели. Этим можно будет заняться во второй части домашнего задания.
#
# Запустим написанную функцию.

# %%
show_images(n_rows = 3, n_cols = 4, dataset = val_dataset)

# %% [markdown]
# ## Шаг 3. Построение нейросети
#
# Запустить данную сеть будет вашим мини-заданием на первую неделю, чтобы было проще участвовать в соревновании.
#
# Данная архитектура будет очень простой и нужна для того, чтобы установить базовое понимание и получить простенький сабмит на Kaggle.
#
# О том, как работают свёртки подробней можно прочитать в документации Pytorch на функцию `Conv2d`:
#
# https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
#
# Калькулятор свёрток:
#
# https://madebyollin.github.io/convnet-calculator/

# %% [markdown]
# #### Модель

# %%
class SimpleCnn(nn.Module):
    """
    Очень простая сверточная нейронная сеть для классификации изображений.

    Эта сеть состоит из пяти сверточных слоев, каждый из которых
    включает в себя операцию свертки, функцию активации ReLU и операцию
    пулинга (max-pooling). На выходе используется полносвязный слой
    для классификации на заданное количество классов.

    Параметры:
    ----------
    n_classes : int
        Количество классов для классификации.

    Примечание:
    ----------
    Входные изображения должны иметь размерность (3, H, W), где
    3 - слои rgb для цветной картинки, а H и W - высота и ширина изображения,
    соответственно. Размер выходного тензора будет равен (n_classes).

    Методы:
    -------
    forward(x):
        Пропускает входные данные через сеть и возвращает логиты для
        каждого класса.
    """

    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )

        self.out = nn.Linear(96 * 5 * 5, n_classes)


    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits

# %% [markdown]
# *Описание слоев*:
#
# 1. размерность входа: $3\times 224 \times 224$
# 2. размерность после 1-го слоя (Conv2d + ReLU + MaxPool2d):  $8 \times 111 \times 111$
# 3. после 2-го слоя: $16 \times 54 \times 54$
# 4. после 3-го слоя: $32 \times 26 \times 26$
# 5. после 4-го слоя: $64 \times 12 \times 12$
# 6. после 5-го слоя: $96 \times 5 \times 5$
# 7. после полносвязного слоя (выход модели): количество классов

# %%
model_simple_cnn = SimpleCnn(n_classes = len(np.unique(train_val_labels)))
model_simple_cnn.to(DEVICE)
torchsummary.summary(model_simple_cnn, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 222, 222]             224
#               ReLU-2          [-1, 8, 222, 222]               0
#          MaxPool2d-3          [-1, 8, 111, 111]               0
#             Conv2d-4         [-1, 16, 109, 109]           1,168
#               ReLU-5         [-1, 16, 109, 109]               0
#          MaxPool2d-6           [-1, 16, 54, 54]               0
#             Conv2d-7           [-1, 32, 52, 52]           4,640
#               ReLU-8           [-1, 32, 52, 52]               0
#          MaxPool2d-9           [-1, 32, 26, 26]               0
#            Conv2d-10           [-1, 64, 24, 24]          18,496
#              ReLU-11           [-1, 64, 24, 24]               0
#         MaxPool2d-12           [-1, 64, 12, 12]               0
#            Conv2d-13           [-1, 96, 10, 10]          55,392
#              ReLU-14           [-1, 96, 10, 10]               0
#         MaxPool2d-15             [-1, 96, 5, 5]               0
#            Linear-16                   [-1, 42]         100,842
# ================================================================
# Total params: 180,762
# Trainable params: 180,762
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 12.31
# Params size (MB): 0.69
# Estimated Total Size (MB): 13.57
# ----------------------------------------------------------------

# %% [markdown]
# ##Шаг 4. Функции для работы с моделью

# %% [markdown]
# #### Задание - напишите функции для работы с моделью

# %% [markdown]
# Обратите внимание, что метрика, которую необходимо оптимизировать в конкурсе -- `f1-score`.
#
# Ниже приводится код для вычисления целевой метрики.

# %%
from sklearn.metrics import f1_score
# пример расчета: f1 = f1_score(actual_labels, y_predicted, average='micro')

# %% [markdown]
# В этом задании может быть полезным сделать, чтобы функция валидации и, возможно, функция обучения на одной эпохе возвращали векторы/тензоры:
# - предсказанного наиболее вероятного класса
# - и фактических меток класса для каждого объекта.
#
# Сама метрика f1, при этом, будет вычисляться не внутри функции, а вне ее, сопоставляя прогнозные и фактические значения, полученные из вывода функции.
#
# Это поможет проанализировать, при предсказании каких классов модель ошибается чаще. Также такой подход может использоваться для обнаружения изображений, которые модель классифицирует неверно.

# %% [markdown]
# Для ускорения вычислений рекомендуется при работе с моделью проводить тензорные вычисления на GPU. Обращаем внимание, для этого необходимо, чтобы и данные, и модель находились на одном устройстве.
#
# Ниже представлен код из предыдущего домашнего задания, который демонстрировал логику циклов обучения и валидации. Ниже в этот код добавлены строки комментарии, показывающие как переносить модель и данные на устройство.
#
#
# ```python
# model.to(DEVICE)  # <- переносим модель на устройство DEVICE
#
# for epoch in range(max_epochs):
#     # режим train
#     model.train()
#     for x_batch, y_batch in train_dataloader:
#         x_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#         y_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#
#         optimizer.zero_grad()
#         outp = model(x_batch)
#         loss = criterion(outp, y_batch)
#         loss.backward()
#         optimizer.step()
#
#         count_metrics(outp, y_batch)  # <-здесь, скорее всего, потребуется перенести данные на cpu, например с помощью метода cpu: metrics.cpu()
#
#      # режим test/eval
#      model.eval()
#      for x_batch, y_batch in val_dataloader:
#         x_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#         y_batch.to(DEVICE)  # <- переносим тензоры данных на устройство DEVICE
#
#         with torch.no_grad():
#             outp = model(x_batch)
#             count_metrics(outp, y_batch) # <-здесь, скорее всего, потребуется перенести данные на cpu
# ```

# %% [markdown]
# Напишите функции:
# - для обучения модели на одной эпохе
# - для валидации модели на одной эпохе
# - для реализации полного цикла обучения
#
# За основу можно взять функции, которые вы написали в предыдущем домашнем задании.

# %%
def train_one_epoch(model, loss_func, optimizer, train_dl):
  model.train()
  total_loss = 0.0
  for xb, yb in train_dl:
    optimizer.zero_grad()
    preds = model(xb.to(DEVICE))
    loss = loss_func(preds, yb.to(DEVICE))
    total_loss += loss.item()
    loss.backward()
    optimizer.step()

  return total_loss / len(train_dl)

# %%
def validate(model, loss_func, val_dl):
  model.eval()
  total_loss = 0.0
  total_correct = 0
  total_predicted = 0
  with torch.no_grad():
    for xb, yb in val_dl:
      preds = model(xb.to(DEVICE))
      loss = loss_func(preds, yb.to(DEVICE))
      total_loss += loss.item()

      _, predicted_labels = torch.max(preds, 1)
      total_correct += (predicted_labels == yb.to(DEVICE)).sum().item()
      total_predicted += xb.size(0)

  avg_loss = total_loss / len(val_dl)
  accuracy = 100 * total_correct / total_predicted
  return avg_loss, accuracy

# %%
def fit(epochs, model, loss_func, optimizer, train_dl, val_dl):
  train_losses = []
  val_losses = []
  valid_accuracies = []

  for epoch in tqdm(range(epochs)):
    train_loss = train_one_epoch(model, loss_func, optimizer, train_dl)
    val_loss, val_accuracy = validate(model, loss_func, val_dl)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    valid_accuracies.append(val_accuracy)

    print(f"EPOCH {epoch + 1} |"
          f"train_loss {train_loss:.4f} |"
          f"val_loss {val_loss:.4f} |"
          f"val_accuracy {val_accuracy:.4f}")
  return train_losses, val_losses, valid_accuracies

# %% [markdown]
# ## Шаг 5. Применение модели к данным

# %% [markdown]
# #### Применение модели к данным

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_simple_cnn.parameters(), lr = 1e-3)

# %% [markdown]
# Запустите обучение сети

# %%
info = fit(10, model_simple_cnn, criterion, optimizer, train_loader, val_loader)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/246 [00:00<?, ?it/s]
#   0%|          | 1/246 [00:00<02:02,  2.00it/s]
#   1%|          | 2/246 [00:00<01:59,  2.03it/s]
#   1%|          | 3/246 [00:01<02:19,  1.74it/s]
#   2%|▏         | 4/246 [00:02<02:09,  1.87it/s]
#   2%|▏         | 5/246 [00:02<02:07,  1.90it/s]
#   2%|▏         | 6/246 [00:03<02:01,  1.97it/s]
#   3%|▎         | 7/246 [00:03<01:59,  2.00it/s]
#   3%|▎         | 8/246 [00:04<01:55,  2.06it/s]
#   4%|▎         | 9/246 [00:04<01:54,  2.06it/s]
#   4%|▍         | 10/246 [00:05<02:09,  1.82it/s]
#   4%|▍         | 11/246 [00:05<02:24,  1.63it/s]
#   5%|▍         | 12/246 [00:06<02:33,  1.52it/s]
#   5%|▌         | 13/246 [00:07<02:20,  1.66it/s]
#   6%|▌         | 14/246 [00:07<02:11,  1.77it/s]
#   6%|▌         | 15/246 [00:08<02:03,  1.88it/s]
#   7%|▋         | 16/246 [00:08<01:57,  1.96it/s]
#   7%|▋         | 17/246 [00:09<01:54,  1.99it/s]
#   7%|▋         | 18/246 [00:09<01:51,  2.04it/s]
#   8%|▊         | 19/246 [00:10<01:49,  2.07it/s]
#   8%|▊         | 20/246 [00:10<01:45,  2.13it/s]
#   9%|▊         | 21/246 [00:10<01:44,  2.15it/s]
#   9%|▉         | 22/246 [00:11<01:44,  2.15it/s]
#   9%|▉         | 23/246 [00:11<01:44,  2.13it/s]
#  10%|▉         | 24/246 [00:12<01:43,  2.14it/s]
#  10%|█         | 25/246 [00:12<01:43,  2.14it/s]
#  11%|█         | 26/246 [00:13<01:42,  2.14it/s]
#  11%|█         | 27/246 [00:13<01:43,  2.13it/s]
#  11%|█▏        | 28/246 [00:14<01:43,  2.11it/s]
#  12%|█▏        | 29/246 [00:14<01:41,  2.15it/s]
#  98%|█████████▊| 240/246 [02:02<00:02,  2.09it/s]
#  98%|█████████▊| 241/246 [02:03<00:02,  2.10it/s]
#  98%|█████████▊| 242/246 [02:03<00:01,  2.07it/s]
#  99%|█████████▉| 243/246 [02:04<00:01,  2.08it/s]
#  99%|█████████▉| 244/246 [02:04<00:00,  2.09it/s]
# 100%|█████████▉| 245/246 [02:05<00:00,  2.03it/s]
# 100%|██████████| 246/246 [02:05<00:00,  1.96it/s]
# 100%|██████████| 10/10 [27:43<00:00, 166.35s/it]
# EPOCH 10 |train_loss 0.1134 |val_loss 1.3101 |val_accuracy 79.4421

# %% [markdown]
# (опционально) Постройте график динамики метрик модели по ходу обучения

# %%
def plot_training(train_losses, valid_losses, valid_accuracies):
    """
    Plots training and validation losses, and validation accuracy over epochs.
    """
    plt.figure(figsize=(12, 9))

    # Plot training and validation losses in the first subplot
    plt.subplot(2, 1, 1)
    plt.xlabel("epoch")
    plt.plot(train_losses, label="train_loss")
    plt.plot(valid_losses, label="valid_loss")
    plt.legend()

    # Plot validation accuracy in the second subplot
    plt.subplot(2, 1, 2)
    plt.xlabel("epoch")
    plt.plot(valid_accuracies, label="valid accuracy")
    plt.legend()

# %%
plot_training(*info)

# %% [markdown]
# ### Ну и что теперь со всем этим делать?

# %% [markdown]
# ![alt text](https://www.indiewire.com/wp-content/uploads/2014/08/the-simpsons.jpg)

# %% [markdown]
# Сделаем классную визуализацию,  чтобы посмотреть насколько сеть уверена в своих ответах.

# %%
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

@torch.no_grad()
def show_images2(n_rows, n_cols, dataset, model):
  # функция выводит изображения в n_rows рядов и n_cols столбцов
  fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(n_cols * 4, n_rows * 4), \
                        sharey=True, sharex=True)

  for fig_x in axs.flatten(): # цикл повторяется (n_rows * n_cols) раз
    random_characters = int(np.random.uniform(0, len(dataset))) # берем случайное число в диапазоне [0; len(dataset))
    im_val, label = dataset[random_characters] # выводим изображение (тензорная форма)
    img_label = " ".join(map(lambda x: x.capitalize(), \
                             label_encoder.inverse_transform([label])[0].split('_')))  # числовую метку класса преобразуем в текстовую и немного отформатируем
    imshow(im_val.data.cpu(), title=img_label, plt_ax=fig_x) # отобразим изображение и метку класса с помощью написанной ранее функции imshow()

    # ниже представлен код для добавления на изображение подписи с вероятностью класса
    actual_text = "Actual : {}".format(img_label)


    font0 = FontProperties()
    font = font0.copy()

    # наша модель возвращает логиты, поэтому для получения вероятностей классов не забываем применить softmax:
    prob_pred = nn.functional.softmax(model(im_val.unsqueeze(0).to(DEVICE)), dim = -1).cpu().numpy()

    predicted_proba = np.max(prob_pred)*100 # берем максимальную вероятность класса
    y_pred = np.argmax(prob_pred) # берем числовую метку класса, для которого вероятность максимальна

    predicted_label = " ".join(map(lambda x: x.capitalize(), \
                             label_encoder.inverse_transform([y_pred])[0].split('_')))
    predicted_text = "{}:\n {:.1f}%".format(predicted_label, predicted_proba)

    fig_x.add_patch(patches.Rectangle((0, 190), 7*len(predicted_label), 25,color='white'))
    fig_x.text(2, 195, predicted_text , horizontalalignment='left', fontproperties=font,
                    verticalalignment='top',fontsize=8, color='black',fontweight='bold')
    fig_x.set_axis_off()

  return None

# %%
show_images2(n_rows = 3, n_cols = 3, dataset = val_dataset, model = model_simple_cnn)

# %% [markdown]
# ## Шаг 6. Submit на Kaggle

# %% [markdown]
# ![alt text](https://i.redd.it/nuaphfioz0211.jpg)

# %% [markdown]
# Создадим loader для тестовых данных

# %%
test_dataset = SimpsonsDataset(test_files, label_encoder = label_encoder, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)

# %% [markdown]
# Воспользуемся функцией predict, которая возвращает предсказанные числовые метки для всех объектов в лоадере.

# %%
def predict(model, loader):
    model.eval()
    all_predictions = torch.tensor([]).to(DEVICE).int()
    print("Test mode...")
    for inputs in tqdm_notebook(loader):
        inputs = inputs.to(DEVICE)

        with torch.no_grad():
            outputs = model(inputs)

            predictions = outputs.argmax(-1).int()
            all_predictions = torch.cat((all_predictions, predictions), 0)
    return all_predictions.cpu()

# %% [markdown]
# Получем предсказание меток классов для тестовых данных:

# %%
predicted_numeric_labels = predict(model_simple_cnn, test_loader)
# Out:
# Test mode...
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
predicted_numeric_labels
# Out:
# tensor([29,  4, 28,  7,  2, 16, 11,  7, 20, 16, 18, 22, 16, 28, 27,  9, 16, 11,
#         16,  0, 22, 29,  9, 24, 15,  2, 17, 17, 28, 11,  2,  7,  2, 28, 22,  0,
#         15, 37, 20,  6,  7, 16,  0, 20, 18,  0, 29,  9,  7, 29,  6,  4,  2, 24,
#          4, 11, 11,  6, 28,  7, 37,  6, 22,  2, 18, 18,  9, 16,  4, 37, 28, 28,
#          9,  9, 11,  4, 16, 28, 17, 17,  7, 24, 28, 17, 37, 28,  7, 29,  0, 17,
#         15, 17, 20, 17, 24, 20, 27, 29, 22,  4,  7, 27,  7, 16, 22, 20,  2,  6,
#         22,  2, 22,  2, 24, 22, 11, 15, 15,  4, 32, 11, 25, 27, 18, 27, 32, 15,
#         18, 20, 37,  7,  2, 24, 32, 29, 16, 27, 15, 20, 25,  2,  9,  6,  6,  4,
#         27, 20,  7, 27, 37,  7, 11, 17, 16, 15,  6, 27, 29,  7, 29, 24, 15, 29,
#         22,  9, 15,  6, 18, 22,  2, 29, 24,  4,  2, 15, 18, 25, 17,  0, 20, 15,
#          7, 15, 15, 17, 18, 18, 16,  6, 15,  7, 11, 16,  2, 29,  4,  6, 24, 16,
#          7,  4,  0, 15, 29,  0,  2,  7, 18, 28, 27, 22, 22, 16, 27,  6,  9,  2,
#          4, 11, 32, 18,  9, 27, 17, 29, 17, 22, 22,  4, 17, 11, 29, 22,  2, 37,
#         15,  9, 11, 20, 16, 25,  2, 27,  2, 11, 17,  0,  6, 29,  6,  4, 29, 29,
#         27, 27,  6, 11, 28, 22,  2, 25, 27, 27,  9, 32, 22, 17, 28, 32, 11, 22,
#          4, 20, 16, 24,  9, 18,  7,  6, 37, 37, 32, 15, 17, 15,  0, 32, 15, 11,
#          6, 17,  7, 29, 18, 28,  7, 32, 20, 18, 37, 37, 15, 27, 18, 29, 18, 18,
#         16,  0, 29, 28, 16,  4, 27, 32, 37, 20, 32, 37,  4, 20,  4, 20, 32, 27,
#         20,  2, 32,  0, 18, 15, 18, 11, 24,  4, 20, 27,  0,  7, 17, 25, 24, 32,
#         11,  9,  9, 16, 29, 32, 16, 17, 29, 25, 37, 24, 18,  4, 18,  9, 32,  4,
#         25, 18, 11,  0, 22, 24, 22, 16, 24, 15, 17, 17, 25, 20, 28, 20, 32, 17,
#         18, 11, 37, 22,  9,  2,  7, 20, 25, 29, 24, 37, 11, 37,  0, 11,  9, 27,
#         28, 27, 28, 24, 28, 17, 11, 32, 29, 32, 11, 18, 25, 16, 37, 32, 32, 32,
#          0, 15, 37, 25,  4, 27, 20,  6,  2, 24, 25,  6,  9,  0, 22, 32, 28, 17,
#         17, 24, 24, 16, 37,  4,  9, 28, 11, 11, 27, 16, 25, 11, 11, 25, 20, 16,
#         18, 32, 18, 11,  0, 28, 37,  9,  9,  7, 18,  0, 22, 37, 28, 24, 15,  7,
#          2, 29, 32, 25, 22, 17,  2, 22, 27, 29, 25, 32, 25, 17, 28, 29, 15, 24,
#         29, 37,  4,  9, 15, 28,  6, 17, 20, 32, 20,  2, 22, 37, 29, 15,  6,  7,
#         17], dtype=torch.int32)

# %% [markdown]
# и преобразуем их в текстовые метки:

# %%
predicted_text_labels = label_encoder.inverse_transform(predicted_numeric_labels)

# %%
predicted_text_labels
# Out:
# array(['nelson_muntz', 'bart_simpson', 'ned_flanders', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'kent_brockman', 'edna_krabappel',
#        'chief_wiggum', 'lisa_simpson', 'kent_brockman', 'lenny_leonard',
#        'marge_simpson', 'kent_brockman', 'ned_flanders', 'moe_szyslak',
#        'comic_book_guy', 'kent_brockman', 'edna_krabappel',
#        'kent_brockman', 'abraham_grampa_simpson', 'marge_simpson',
#        'nelson_muntz', 'comic_book_guy', 'mayor_quimby', 'homer_simpson',
#        'apu_nahasapeemapetilon', 'krusty_the_clown', 'krusty_the_clown',
#        'ned_flanders', 'edna_krabappel', 'apu_nahasapeemapetilon',
#        'chief_wiggum', 'apu_nahasapeemapetilon', 'ned_flanders',
#        'marge_simpson', 'abraham_grampa_simpson', 'homer_simpson',
#        'sideshow_bob', 'lisa_simpson', 'charles_montgomery_burns',
#        'chief_wiggum', 'kent_brockman', 'abraham_grampa_simpson',
#        'lisa_simpson', 'lenny_leonard', 'abraham_grampa_simpson',
#        'nelson_muntz', 'comic_book_guy', 'chief_wiggum', 'nelson_muntz',
#        'charles_montgomery_burns', 'bart_simpson',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'bart_simpson',
#        'edna_krabappel', 'edna_krabappel', 'charles_montgomery_burns',
#        'ned_flanders', 'chief_wiggum', 'sideshow_bob',
#        'charles_montgomery_burns', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'lenny_leonard', 'lenny_leonard',
#        'comic_book_guy', 'kent_brockman', 'bart_simpson', 'sideshow_bob',
#        'ned_flanders', 'ned_flanders', 'comic_book_guy', 'comic_book_guy',
#        'edna_krabappel', 'bart_simpson', 'kent_brockman', 'ned_flanders',
#        'krusty_the_clown', 'krusty_the_clown', 'chief_wiggum',
#        'mayor_quimby', 'ned_flanders', 'krusty_the_clown', 'sideshow_bob',
#        'ned_flanders', 'chief_wiggum', 'nelson_muntz',
#        'abraham_grampa_simpson', 'krusty_the_clown', 'homer_simpson',
#        'krusty_the_clown', 'lisa_simpson', 'krusty_the_clown',
#        'mayor_quimby', 'lisa_simpson', 'moe_szyslak', 'nelson_muntz',
#        'marge_simpson', 'bart_simpson', 'chief_wiggum', 'moe_szyslak',
#        'chief_wiggum', 'kent_brockman', 'marge_simpson', 'lisa_simpson',
#        'apu_nahasapeemapetilon', 'charles_montgomery_burns',
#        'marge_simpson', 'apu_nahasapeemapetilon', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'marge_simpson',
#        'edna_krabappel', 'homer_simpson', 'homer_simpson', 'bart_simpson',
#        'principal_skinner', 'edna_krabappel', 'milhouse_van_houten',
#        'moe_szyslak', 'lenny_leonard', 'moe_szyslak', 'principal_skinner',
#        'homer_simpson', 'lenny_leonard', 'lisa_simpson', 'sideshow_bob',
#        'chief_wiggum', 'apu_nahasapeemapetilon', 'mayor_quimby',
#        'principal_skinner', 'nelson_muntz', 'kent_brockman',
#        'moe_szyslak', 'homer_simpson', 'lisa_simpson',
#        'milhouse_van_houten', 'apu_nahasapeemapetilon', 'comic_book_guy',
#        'charles_montgomery_burns', 'charles_montgomery_burns',
#        'bart_simpson', 'moe_szyslak', 'lisa_simpson', 'chief_wiggum',
#        'moe_szyslak', 'sideshow_bob', 'chief_wiggum', 'edna_krabappel',
#        'krusty_the_clown', 'kent_brockman', 'homer_simpson',
#        'charles_montgomery_burns', 'moe_szyslak', 'nelson_muntz',
#        'chief_wiggum', 'nelson_muntz', 'mayor_quimby', 'homer_simpson',
#        'nelson_muntz', 'marge_simpson', 'comic_book_guy', 'homer_simpson',
#        'charles_montgomery_burns', 'lenny_leonard', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'nelson_muntz', 'mayor_quimby',
#        'bart_simpson', 'apu_nahasapeemapetilon', 'homer_simpson',
#        'lenny_leonard', 'milhouse_van_houten', 'krusty_the_clown',
#        'abraham_grampa_simpson', 'lisa_simpson', 'homer_simpson',
#        'chief_wiggum', 'homer_simpson', 'homer_simpson',
#        'krusty_the_clown', 'lenny_leonard', 'lenny_leonard',
#        'kent_brockman', 'charles_montgomery_burns', 'homer_simpson',
#        'chief_wiggum', 'edna_krabappel', 'kent_brockman',
#        'apu_nahasapeemapetilon', 'nelson_muntz', 'bart_simpson',
#        'charles_montgomery_burns', 'mayor_quimby', 'kent_brockman',
#        'chief_wiggum', 'bart_simpson', 'abraham_grampa_simpson',
#        'homer_simpson', 'nelson_muntz', 'abraham_grampa_simpson',
#        'apu_nahasapeemapetilon', 'chief_wiggum', 'lenny_leonard',
#        'ned_flanders', 'moe_szyslak', 'marge_simpson', 'marge_simpson',
#        'kent_brockman', 'moe_szyslak', 'charles_montgomery_burns',
#        'comic_book_guy', 'apu_nahasapeemapetilon', 'bart_simpson',
#        'edna_krabappel', 'principal_skinner', 'lenny_leonard',
#        'comic_book_guy', 'moe_szyslak', 'krusty_the_clown',
#        'nelson_muntz', 'krusty_the_clown', 'marge_simpson',
#        'marge_simpson', 'bart_simpson', 'krusty_the_clown',
#        'edna_krabappel', 'nelson_muntz', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'sideshow_bob', 'homer_simpson',
#        'comic_book_guy', 'edna_krabappel', 'lisa_simpson',
#        'kent_brockman', 'milhouse_van_houten', 'apu_nahasapeemapetilon',
#        'moe_szyslak', 'apu_nahasapeemapetilon', 'edna_krabappel',
#        'krusty_the_clown', 'abraham_grampa_simpson',
#        'charles_montgomery_burns', 'nelson_muntz',
#        'charles_montgomery_burns', 'bart_simpson', 'nelson_muntz',
#        'nelson_muntz', 'moe_szyslak', 'moe_szyslak',
#        'charles_montgomery_burns', 'edna_krabappel', 'ned_flanders',
#        'marge_simpson', 'apu_nahasapeemapetilon', 'milhouse_van_houten',
#        'moe_szyslak', 'moe_szyslak', 'comic_book_guy',
#        'principal_skinner', 'marge_simpson', 'krusty_the_clown',
#        'ned_flanders', 'principal_skinner', 'edna_krabappel',
#        'marge_simpson', 'bart_simpson', 'lisa_simpson', 'kent_brockman',
#        'mayor_quimby', 'comic_book_guy', 'lenny_leonard', 'chief_wiggum',
#        'charles_montgomery_burns', 'sideshow_bob', 'sideshow_bob',
#        'principal_skinner', 'homer_simpson', 'krusty_the_clown',
#        'homer_simpson', 'abraham_grampa_simpson', 'principal_skinner',
#        'homer_simpson', 'edna_krabappel', 'charles_montgomery_burns',
#        'krusty_the_clown', 'chief_wiggum', 'nelson_muntz',
#        'lenny_leonard', 'ned_flanders', 'chief_wiggum',
#        'principal_skinner', 'lisa_simpson', 'lenny_leonard',
#        'sideshow_bob', 'sideshow_bob', 'homer_simpson', 'moe_szyslak',
#        'lenny_leonard', 'nelson_muntz', 'lenny_leonard', 'lenny_leonard',
#        'kent_brockman', 'abraham_grampa_simpson', 'nelson_muntz',
#        'ned_flanders', 'kent_brockman', 'bart_simpson', 'moe_szyslak',
#        'principal_skinner', 'sideshow_bob', 'lisa_simpson',
#        'principal_skinner', 'sideshow_bob', 'bart_simpson',
#        'lisa_simpson', 'bart_simpson', 'lisa_simpson',
#        'principal_skinner', 'moe_szyslak', 'lisa_simpson',
#        'apu_nahasapeemapetilon', 'principal_skinner',
#        'abraham_grampa_simpson', 'lenny_leonard', 'homer_simpson',
#        'lenny_leonard', 'edna_krabappel', 'mayor_quimby', 'bart_simpson',
#        'lisa_simpson', 'moe_szyslak', 'abraham_grampa_simpson',
#        'chief_wiggum', 'krusty_the_clown', 'milhouse_van_houten',
#        'mayor_quimby', 'principal_skinner', 'edna_krabappel',
#        'comic_book_guy', 'comic_book_guy', 'kent_brockman',
#        'nelson_muntz', 'principal_skinner', 'kent_brockman',
#        'krusty_the_clown', 'nelson_muntz', 'milhouse_van_houten',
#        'sideshow_bob', 'mayor_quimby', 'lenny_leonard', 'bart_simpson',
#        'lenny_leonard', 'comic_book_guy', 'principal_skinner',
#        'bart_simpson', 'milhouse_van_houten', 'lenny_leonard',
#        'edna_krabappel', 'abraham_grampa_simpson', 'marge_simpson',
#        'mayor_quimby', 'marge_simpson', 'kent_brockman', 'mayor_quimby',
#        'homer_simpson', 'krusty_the_clown', 'krusty_the_clown',
#        'milhouse_van_houten', 'lisa_simpson', 'ned_flanders',
#        'lisa_simpson', 'principal_skinner', 'krusty_the_clown',
#        'lenny_leonard', 'edna_krabappel', 'sideshow_bob', 'marge_simpson',
#        'comic_book_guy', 'apu_nahasapeemapetilon', 'chief_wiggum',
#        'lisa_simpson', 'milhouse_van_houten', 'nelson_muntz',
#        'mayor_quimby', 'sideshow_bob', 'edna_krabappel', 'sideshow_bob',
#        'abraham_grampa_simpson', 'edna_krabappel', 'comic_book_guy',
#        'moe_szyslak', 'ned_flanders', 'moe_szyslak', 'ned_flanders',
#        'mayor_quimby', 'ned_flanders', 'krusty_the_clown',
#        'edna_krabappel', 'principal_skinner', 'nelson_muntz',
#        'principal_skinner', 'edna_krabappel', 'lenny_leonard',
#        'milhouse_van_houten', 'kent_brockman', 'sideshow_bob',
#        'principal_skinner', 'principal_skinner', 'principal_skinner',
#        'abraham_grampa_simpson', 'homer_simpson', 'sideshow_bob',
#        'milhouse_van_houten', 'bart_simpson', 'moe_szyslak',
#        'lisa_simpson', 'charles_montgomery_burns',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'milhouse_van_houten',
#        'charles_montgomery_burns', 'comic_book_guy',
#        'abraham_grampa_simpson', 'marge_simpson', 'principal_skinner',
#        'ned_flanders', 'krusty_the_clown', 'apu_nahasapeemapetilon',
#        'abraham_grampa_simpson', 'lisa_simpson', 'lisa_simpson',
#        'apu_nahasapeemapetilon', 'lisa_simpson', 'principal_skinner',
#        'kent_brockman', 'nelson_muntz', 'comic_book_guy',
#        'milhouse_van_houten', 'principal_skinner', 'comic_book_guy',
#        'principal_skinner', 'lisa_simpson', 'abraham_grampa_simpson',
#        'edna_krabappel', 'ned_flanders', 'krusty_the_clown',
#        'bart_simpson', 'lisa_simpson', 'lenny_leonard', 'homer_simpson',
#        'apu_nahasapeemapetilon', 'comic_book_guy', 'comic_book_guy',
#        'bart_simpson', 'marge_simpson', 'charles_montgomery_burns',
#        'bart_simpson', 'comic_book_guy', 'marge_simpson', 'mayor_quimby',
#        'krusty_the_clown', 'krusty_the_clown', 'marge_simpson',
#        'milhouse_van_houten', 'kent_brockman', 'edna_krabappel',
#        'lisa_simpson', 'principal_skinner', 'bart_simpson',
#        'abraham_grampa_simpson', 'milhouse_van_houten', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'selma_bouvier', 'krusty_the_clown',
#        'ned_flanders', 'comic_book_guy', 'homer_simpson', 'lisa_simpson',
#        'abraham_grampa_simpson', 'lenny_leonard', 'ned_flanders',
#        'chief_wiggum', 'abraham_grampa_simpson', 'moe_szyslak',
#        'milhouse_van_houten', 'lisa_simpson', 'homer_simpson',
#        'nelson_muntz', 'abraham_grampa_simpson', 'principal_skinner',
#        'nelson_muntz', 'kent_brockman', 'krusty_the_clown',
#        'homer_simpson', 'marge_simpson', 'sideshow_bob', 'ned_flanders',
#        'lenny_leonard', 'milhouse_van_houten', 'krusty_the_clown',
#        'apu_nahasapeemapetilon', 'mayor_quimby', 'chief_wiggum',
#        'bart_simpson', 'marge_simpson', 'milhouse_van_houten',
#        'nelson_muntz', 'mayor_quimby', 'krusty_the_clown',
#        'kent_brockman', 'moe_szyslak', 'apu_nahasapeemapetilon',
#        'mayor_quimby', 'sideshow_bob', 'mayor_quimby',
#        'principal_skinner', 'nelson_muntz', 'bart_simpson',
#        'apu_nahasapeemapetilon', 'nelson_muntz', 'abraham_grampa_simpson',
#        'ned_flanders', 'moe_szyslak', 'abraham_grampa_simpson',
#        'kent_brockman', 'abraham_grampa_simpson', 'moe_szyslak',
#        'comic_book_guy', 'kent_brockman', 'krusty_the_clown',
#        'chief_wiggum', 'homer_simpson', 'lisa_simpson', 'lenny_leonard',
#        'apu_nahasapeemapetilon', 'comic_book_guy',
#        'apu_nahasapeemapetilon', 'abraham_grampa_simpson', 'nelson_muntz',
#        'bart_simpson', 'moe_szyslak', 'chief_wiggum', 'ned_flanders',
#        'principal_skinner', 'kent_brockman', 'ned_flanders',
#        'charles_montgomery_burns', 'comic_book_guy', 'krusty_the_clown',
#        'bart_simpson', 'krusty_the_clown', 'bart_simpson', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'moe_szyslak', 'homer_simpson',
#        'principal_skinner', 'comic_book_guy', 'abraham_grampa_simpson',
#        'homer_simpson', 'apu_nahasapeemapetilon', 'chief_wiggum',
#        'chief_wiggum', 'chief_wiggum', 'moe_szyslak', 'marge_simpson',
#        'bart_simpson', 'mayor_quimby', 'lisa_simpson', 'lisa_simpson',
#        'nelson_muntz', 'ned_flanders', 'sideshow_bob', 'chief_wiggum',
#        'krusty_the_clown', 'bart_simpson', 'marge_simpson',
#        'ned_flanders', 'nelson_muntz', 'mayor_quimby', 'nelson_muntz',
#        'abraham_grampa_simpson', 'ned_flanders', 'lenny_leonard',
#        'abraham_grampa_simpson', 'bart_simpson', 'mayor_quimby',
#        'lenny_leonard', 'abraham_grampa_simpson', 'ned_flanders',
#        'sideshow_bob', 'marge_simpson', 'homer_simpson', 'lisa_simpson',
#        'homer_simpson', 'principal_skinner', 'ned_flanders',
#        'nelson_muntz', 'moe_szyslak', 'chief_wiggum',
#        'apu_nahasapeemapetilon', 'sideshow_bob', 'chief_wiggum',
#        'marge_simpson', 'krusty_the_clown', 'marge_simpson',
#        'abraham_grampa_simpson', 'sideshow_bob', 'lenny_leonard',
#        'lenny_leonard', 'charles_montgomery_burns', 'kent_brockman',
#        'principal_skinner', 'ned_flanders', 'lisa_simpson',
#        'lenny_leonard', 'charles_montgomery_burns', 'principal_skinner',
#        'nelson_muntz', 'abraham_grampa_simpson', 'comic_book_guy',
#        'chief_wiggum', 'homer_simpson', 'edna_krabappel', 'sideshow_bob',
#        'moe_szyslak', 'comic_book_guy', 'moe_szyslak',
#        'milhouse_van_houten', 'charles_montgomery_burns', 'kent_brockman',
#        'marge_simpson', 'homer_simpson', 'nelson_muntz',
#        'charles_montgomery_burns', 'nelson_muntz', 'nelson_muntz',
#        'ned_flanders', 'nelson_muntz', 'mayor_quimby', 'kent_brockman',
#        'ned_flanders', 'lisa_simpson', 'sideshow_bob', 'homer_simpson',
#        'nelson_muntz', 'lenny_leonard', 'kent_brockman', 'moe_szyslak',
#        'bart_simpson', 'bart_simpson', 'kent_brockman', 'nelson_muntz',
#        'charles_montgomery_burns', 'moe_szyslak', 'milhouse_van_houten',
#        'principal_skinner', 'apu_nahasapeemapetilon', 'krusty_the_clown',
#        'milhouse_van_houten', 'bart_simpson', 'ned_flanders',
#        'abraham_grampa_simpson', 'abraham_grampa_simpson',
#        'kent_brockman', 'apu_nahasapeemapetilon', 'comic_book_guy',
#        'chief_wiggum', 'moe_szyslak', 'kent_brockman',
#        'milhouse_van_houten', 'apu_nahasapeemapetilon', 'marge_simpson',
#        'lisa_simpson', 'moe_szyslak', 'lenny_leonard', 'lenny_leonard',
#        'milhouse_van_houten', 'charles_montgomery_burns',
#        'edna_krabappel', 'mayor_quimby', 'moe_szyslak',
#        'apu_nahasapeemapetilon', 'principal_skinner', 'kent_brockman',
#        'lenny_leonard', 'charles_montgomery_burns', 'mayor_quimby',
#        'homer_simpson', 'groundskeeper_willie', 'krusty_the_clown',
#        'lenny_leonard', 'lisa_simpson', 'charles_montgomery_burns',
#        'bart_simpson', 'kent_brockman', 'apu_nahasapeemapetilon',
#        'apu_nahasapeemapetilon', 'sideshow_bob', 'edna_krabappel',
#        'charles_montgomery_burns', 'comic_book_guy', 'sideshow_bob',
#        'charles_montgomery_burns', 'chief_wiggum', 'bart_simpson',
#        'abraham_grampa_simpson', 'abraham_grampa_simpson', 'mayor_quimby',
#        'edna_krabappel', 'edna_krabappel', 'abraham_grampa_simpson',
#        'lenny_leonard', 'lisa_simpson', 'milhouse_van_houten',
#        'mayor_quimby', 'apu_nahasapeemapetilon', 'edna_krabappel',
#        'mayor_quimby', 'sideshow_bob', 'sideshow_bob',
#        'principal_skinner', 'chief_wiggum', 'moe_szyslak',
#        'comic_book_guy', 'chief_wiggum', 'krusty_the_clown',
#        'marge_simpson', 'ned_flanders', 'principal_skinner',
#        'kent_brockman', 'moe_szyslak', 'apu_nahasapeemapetilon',
#        'chief_wiggum', 'ned_flanders', 'bart_simpson', 'bart_simpson',
#        'marge_simpson', 'moe_szyslak', 'edna_krabappel',
#        'abraham_grampa_simpson', 'bart_simpson', 'comic_book_guy',
#        'abraham_grampa_simpson', 'lisa_simpson', 'milhouse_van_houten',
#        'nelson_muntz', 'kent_brockman', 'principal_skinner',
#        'kent_brockman', 'charles_montgomery_burns', 'milhouse_van_houten',
#        'principal_skinner', 'lisa_simpson', 'homer_simpson',
#        'chief_wiggum', 'milhouse_van_houten', 'ned_flanders',
#        'principal_skinner', 'kent_brockman', 'edna_krabappel',
#        'mayor_quimby', 'comic_book_guy', 'charles_montgomery_burns',
#        'chief_wiggum', 'ned_flanders', 'sideshow_bob', 'ned_flanders',
#        'nelson_muntz', 'moe_szyslak', 'principal_skinner', 'sideshow_bob',
#        'principal_skinner', 'milhouse_van_houten',
#        'abraham_grampa_simpson', 'homer_simpson', 'chief_wiggum',
#        'milhouse_van_houten', 'edna_krabappel', 'moe_szyslak',
#        'milhouse_van_houten', 'moe_szyslak', 'principal_skinner',
#        'edna_krabappel', 'principal_skinner', 'lisa_simpson',
#        'comic_book_guy', 'apu_nahasapeemapetilon', 'edna_krabappel',
#        'kent_brockman', 'principal_skinner', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'homer_simpson', 'moe_szyslak',
#        'bart_simpson', 'abraham_grampa_simpson', 'moe_szyslak',
#        'marge_simpson', 'ned_flanders', 'homer_simpson', 'comic_book_guy',
#        'apu_nahasapeemapetilon', 'comic_book_guy', 'homer_simpson',
#        'sideshow_bob', 'homer_simpson', 'abraham_grampa_simpson',
#        'chief_wiggum', 'nelson_muntz', 'charles_montgomery_burns',
#        'edna_krabappel', 'abraham_grampa_simpson', 'edna_krabappel',
#        'bart_simpson', 'moe_szyslak', 'charles_montgomery_burns',
#        'chief_wiggum', 'bart_simpson', 'homer_simpson', 'ned_flanders',
#        'kent_brockman', 'krusty_the_clown', 'barney_gumble',
#        'comic_book_guy', 'marge_simpson', 'charles_montgomery_burns',
#        'chief_wiggum', 'marge_simpson', 'sideshow_bob', 'lenny_leonard',
#        'lisa_simpson', 'principal_skinner', 'abraham_grampa_simpson',
#        'kent_brockman', 'mayor_quimby', 'marge_simpson', 'sideshow_bob',
#        'marge_simpson', 'lisa_simpson', 'mayor_quimby',
#        'charles_montgomery_burns', 'marge_simpson', 'homer_simpson',
#        'edna_krabappel', 'krusty_the_clown', 'marge_simpson',
#        'nelson_muntz', 'krusty_the_clown', 'lisa_simpson', 'lisa_simpson',
#        'nelson_muntz', 'principal_skinner', 'milhouse_van_houten',
#        'comic_book_guy', 'homer_simpson', 'homer_simpson',
#        'apu_nahasapeemapetilon', 'lenny_leonard', 'sideshow_bob',
#        'abraham_grampa_simpson', 'chief_wiggum', 'lisa_simpson',
#        'lisa_simpson', 'kent_brockman', 'abraham_grampa_simpson',
#        'marge_simpson', 'bart_simpson', 'principal_skinner',
#        'homer_simpson', 'charles_montgomery_burns', 'principal_skinner',
#        'sideshow_bob', 'ned_flanders', 'principal_skinner',
#        'krusty_the_clown', 'charles_montgomery_burns', 'sideshow_bob',
#        'abraham_grampa_simpson', 'abraham_grampa_simpson',
#        'milhouse_van_houten', 'moe_szyslak', 'ned_flanders',
#        'comic_book_guy', 'nelson_muntz', 'marge_simpson',
#        'apu_nahasapeemapetilon', 'moe_szyslak',
#        'charles_montgomery_burns', 'nelson_muntz', 'comic_book_guy',
#        'principal_skinner', 'ned_flanders', 'moe_szyslak', 'sideshow_bob',
#        'ned_flanders', 'moe_szyslak', 'chief_wiggum', 'mayor_quimby',
#        'lisa_simpson', 'bart_simpson', 'marge_simpson', 'mayor_quimby',
#        'apu_nahasapeemapetilon', 'krusty_the_clown', 'sideshow_bob',
#        'chief_wiggum', 'moe_szyslak', 'lenny_leonard',
#        'charles_montgomery_burns', 'comic_book_guy', 'bart_simpson',
#        'krusty_the_clown', 'mayor_quimby', 'mayor_quimby',
#        'kent_brockman', 'sideshow_bob', 'bart_simpson', 'comic_book_guy',
#        'ned_flanders', 'edna_krabappel', 'edna_krabappel', 'moe_szyslak',
#        'kent_brockman', 'milhouse_van_houten', 'edna_krabappel',
#        'edna_krabappel', 'milhouse_van_houten', 'lisa_simpson',
#        'kent_brockman', 'lenny_leonard', 'principal_skinner',
#        'lenny_leonard', 'edna_krabappel', 'abraham_grampa_simpson',
#        'ned_flanders', 'sideshow_bob', 'comic_book_guy', 'comic_book_guy',
#        'chief_wiggum', 'lenny_leonard', 'abraham_grampa_simpson',
#        'marge_simpson', 'sideshow_bob', 'ned_flanders', 'mayor_quimby',
#        'homer_simpson', 'chief_wiggum', 'apu_nahasapeemapetilon',
#        'nelson_muntz', 'principal_skinner', 'milhouse_van_houten',
#        'marge_simpson', 'krusty_the_clown', 'apu_nahasapeemapetilon',
#        'marge_simpson', 'moe_szyslak', 'nelson_muntz',
#        'milhouse_van_houten', 'principal_skinner', 'milhouse_van_houten',
#        'krusty_the_clown', 'ned_flanders', 'nelson_muntz',
#        'homer_simpson', 'mayor_quimby', 'nelson_muntz', 'sideshow_bob',
#        'bart_simpson', 'comic_book_guy', 'homer_simpson', 'ned_flanders',
#        'charles_montgomery_burns', 'krusty_the_clown', 'lisa_simpson',
#        'principal_skinner', 'lisa_simpson', 'apu_nahasapeemapetilon',
#        'marge_simpson', 'sideshow_bob', 'nelson_muntz', 'homer_simpson',
#        'charles_montgomery_burns', 'chief_wiggum', 'krusty_the_clown'],
#       dtype='<U24')

# %% [markdown]
# Загрузим пример файла для загрузки на Kaggle (проверьте путь, по которому у вас лежит файл sample_submission.csv и при необходимости скорректируйте путь в коде ниже):

# %%
import pandas as pd
sample_submission = pd.read_csv("/content/sample_submission.csv")
sample_submission.head(10)
# Out:
#          Id      Expected
# 0  img0.jpg  bart_simpson
# 1  img1.jpg  bart_simpson
# 2  img2.jpg  bart_simpson
# 3  img3.jpg  bart_simpson
# 4  img4.jpg  bart_simpson
# 5  img5.jpg  bart_simpson
# 6  img6.jpg  bart_simpson
# 7  img7.jpg  bart_simpson
# 8  img8.jpg  bart_simpson
# 9  img9.jpg  bart_simpson

# %%
my_submission = pd.DataFrame({'Id': [path.name for path in test_files], 'Expected': predicted_text_labels})
my_submission.head(10)
# Out:
#            Id                Expected
# 0    img0.jpg            nelson_muntz
# 1    img1.jpg            bart_simpson
# 2   img10.jpg            ned_flanders
# 3  img100.jpg            chief_wiggum
# 4  img101.jpg  apu_nahasapeemapetilon
# 5  img102.jpg           kent_brockman
# 6  img103.jpg          edna_krabappel
# 7  img104.jpg            chief_wiggum
# 8  img105.jpg            lisa_simpson
# 9  img106.jpg           kent_brockman

# %%
# TODO : сделайте сабмит (это важно, если Вы не справляетесь, но дошли до этой ячейки, то сообщите в чат и Вам помогут)

# %%
my_submission.to_csv('simple_cnn_baseline.csv', index=False)

# %% [markdown]
# ## Приключение?
#
# А теперь самое интересное, мы сделали простенькую сверточную сеть и смогли отправить сабмит, но получившийся score нас явно не устраивает. Надо с этим что-то сделать.
#
# Вам предлагается творческая и исследовательская свобода в том, как вы будете улучшать score модели. Вот некоторые направления, которые вы, возможно, захотите попробовать:
# 1. Работа с датасетом:
# * Попробуйте увеличить разнообразие обучающей выборки при помощи аугментации ([ссылка 1](https://habr.com/ru/companies/smartengines/articles/264677/), [ссылка 2](https://www.geeksforgeeks.org/python-data-augmentation/));
# * Используя результаты функции eval_one_epoch, вы можете посмотреть, как метрика f1-score внутри класса связана с размером самого класса в обучающей выборке. Скорее всего, вы заметите прямую зависимость. Решением может быть увеличение размеров слабо представленных классов. Сделать это можно, вручную добавив этот функционал в SimpsonsDataset или воспользовавшись инструментом WeightedRandomSampler.
#
# * Также вы можете изучить, какие изображения модель классифицирует неверно. Можно просто посмотреть неверно классифицированные изображения в валидационном датасете. Можно попробовать более фундаментальный подход - создать dataloader из всех изображений обучающей и валидационной выборки в SimpsonsDataset c режимом 'val', прогнать данные через обученную модель simple_cnn. Более того, можно обучить несколько моделей с разной архитектурой, и прогнать объединенный датасет через все эти модели - и выделить те изображения, в классификации которых ошиблись несколько моделей.
#
# * Это поможет понять, как качество и чистота исходных данных влияет на результаты обучения модели. Если вы обнаружите ошибки в simpsons_dataset и решите их исправить или удалить некоторые изображения из обучающей выборки - сделайте это в ноутбуке, чтобы при проверке можно было повторить результаты работы вашего кода.
#
# 2. Работа с архитектурой сети:
# * учим дольше и изменяем (подбираем) гиперпараметры: learning rate, batch size, нормализация картинки и вот это всё;
# * добавление/удаление свёрточных и полносвязных слоёв;
# * А еще есть где пулинги и батч-норм!
#
# 3. Применение техник, описанных в предыдущих пунктах, позволяет добиться довольно высоких результатов. Но вы можете попробовать файнтютинг и трансферлёнинг:
# * ну разве это deep learning? Вот ResNet и Inception, которые можно зафайнтьюнить под наши данные, вот это я понимаю (можно и обучить в колабе, а можно и [готовые](https://github.com/Cadene/pretrained-models.pytorch) скачать).
#
# 4. Улучшение оптимизации:
# * ну разве Адам наше все? [adamW](https://www.fast.ai/2018/07/02/adam-weight-decay/) для практика, [статейка для любителей](https://openreview.net/pdf?id=ryQu7f-RZ) (очень хороший анализ), [наши ](https://github.com/MichaelKonobeev/adashift/) эксперименты для заинтересованных.
#
# 5. Наконец, возможно, стоит подумать об ансамблях
#
#
# Надеюсь, что у Вас получится!
